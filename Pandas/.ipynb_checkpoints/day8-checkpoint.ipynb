# %%
import pandas as pd

# %%
s= pd.Series(['A','B','C'])

# %%
df1 = pd.DataFrame({
    "City": ['Mumbai', 'Bhubaneswar','Bengaluru'],
    "temp": [12,13,19],
    "wind": [5,6,23]})

# %%
df2 = pd.DataFrame({
    "City": ['Mumbai', 'Bhubaneswar','Bengaluru'],
    "temp": [12,13,19],
    "wind": [5,6,23]})

# %%
df = pd.concat([df1,s], axis=1)
df
# Out:
#           City  temp  wind  0
# 0       Mumbai    12     5  A
# 1  Bhubaneswar    13     6  B
# 2    Bengaluru    19    23  C
